# %% [markdown]
# # klusterlash algoritimlari

# %% [markdown]
# # (1) partioned-based (gruhlash) yordamida klusterlash

# %% [markdown]
# # K-means, k-median, Fuzzy c-means
# - O'RTA VA KATTA DATASETLARGA QO'LLASH TAVSIYA QILINADI

# %% [markdown]
# # (2) Hierarchical (iyerarxik) klasterlash

# %% [markdown]
# ## kelib chiqish shajarasiga qarab gruhlash(dnk misolida)
# ### kichik hajmdagi datasetlar uchun tavsiya qilinadi
# # bu yerda natija shajara korinishida boladi

# %% [markdown]
# # (3) Zichlikka asoslangan (density-based) klasterlash

# %% [markdown]
# ### biz bu yerda malumotlarni zichligiga qarab gruhlaymiz
# ## natija turli hajmdagi klasterlar korinishida boladi
# ## xatolari kop datasetlar uchun tavsiya qilinadi

# %%
from IPython.display import Image

# %%
Image('clustering-algoritims.jpg', width=600)
